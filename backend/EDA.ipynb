# %%
import requests

response = requests.get("https://services6.arcgis.com/bdPqSfflsdgFRVVM/arcgis/rest/services/crime_data_1_auto_update/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")

# %%
import csv 
import pandas as pd
import numpy as np

# %%
Crime2023Part1 = pd.read_csv('./datasets/Crime2023Part1.csv')
Crime2023Part2 = pd.read_csv('./datasets/Crime2023Part2.csv')
Crime2024Part2 = pd.read_csv('./datasets/Crime2024Part2.csv')
Crime2024Part1 = pd.read_csv('./datasets/Crime2024Part1.csv')
Crime2018Part1 = pd.read_csv('./datasets/Crime2018Part1.csv')

# %%
Crime2024Part1.dropna(inplace=True)
Crime2023Part2.dropna(inplace=True)
Crime2023Part1.dropna(inplace=True)
Crime2024Part2.dropna(inplace=True)
Crime2018Part1.dropna(inplace=True)

# %%
Crime2023Part1
Crime2023Part2
Crime2024Part2
# Out:
#                 X             Y                 DATEEND  TIMESTART  TIMEEND  \
# 0   -8.479661e+06  5.317442e+06  2024/01/20 05:00:00+00        355      355
# 1   -8.472376e+06  5.321695e+06  2024/01/20 05:00:00+00        941     1000
# 2   -8.477444e+06  5.319086e+06  2024/01/21 05:00:00+00         11       11
# 3   -8.480678e+06  5.319991e+06  2024/01/13 05:00:00+00        941      941
# 4   -8.476041e+06  5.321574e+06  2024/01/20 05:00:00+00       1056     1056
# ..            ...           ...                     ...        ...      ...
# 856 -8.476023e+06  5.321743e+06  2024/01/13 05:00:00+00          1       15
# 857 -8.476075e+06  5.318279e+06  2024/01/13 05:00:00+00        313      313
# 858 -8.476856e+06  5.316991e+06  2024/01/12 05:00:00+00       2318     2318
# 859 -8.476908e+06  5.321811e+06  2024/01/13 05:00:00+00        136      136
# 860 -8.477362e+06  5.321635e+06  2024/01/13 05:00:00+00        854      854
#
# ...

# %%
print(Crime2023Part1.columns)
print(Crime2023Part2.columns)
print(Crime2024Part2.columns)
print(Crime2024Part1.columns)
# Out:
# Index(['X', 'Y', 'DATEEND', 'TIMESTART', 'TIMEEND', 'ADDRESS', 'Arrest',
#        'LarcenyCode', 'CODE_DEFINED', 'LAT', 'LONG', 'ObjectId'],
#       dtype='object')
# Index(['X', 'Y', 'DATEEND', 'TIMESTART', 'TIMEEND', 'ADDRESS', 'QualityOfLife',
#        'CODE_DEFINED', 'LAT', 'LONG', 'ObjectId'],
#       dtype='object')
# Index(['X', 'Y', 'DATEEND', 'TIMESTART', 'TIMEEND', 'ADDRESS', 'QualityOfLife',
#        'CODE_DEFINED', 'LAT', 'LONG', 'ObjectId'],
#       dtype='object')
# Index(['X', 'Y', 'DATEEND', 'TIMESTART', 'TIMEEND', 'ADDRESS', 'Arrest',
#        'LarcenyCode', 'CODE_DEFINED', 'LAT', 'LONG', 'ObjectId'],
#       dtype='object')

# %%
Crime2023Part1.ADDRESS.unique
# Out:
# <bound method Series.unique of 4                         1 DESTINY USA DR
# 5                         1 DESTINY USA DR
# 13                        1 DESTINY USA DR
# 14      0 S WARREN ST & E WATER ST
# 18                        1 DESTINY USA DR
#                        ...
# 6581                      800 BURNET AV
# 6584                      800 BEAR ST
# 6607                  800 E BRIGHTON AV
# 6612                  800 E WILLOW ST
# 6616                      800 ERIE BLVD W
# Name: ADDRESS, Length: 752, dtype: object>

# %%
Crime2023Part1[Crime2023Part1['CODE_DEFINED'] == 'LARCENY']
# Out:
#                  X             Y                 DATEEND TIMESTART  TIMEEND  \
# 4    -8.479620e+06  5.322322e+06  2023/08/24 00:00:00+00      1341     1341
# 5    -8.479620e+06  5.322322e+06  2023/08/24 00:00:00+00      1730     1730
# 13   -8.479620e+06  5.322322e+06  2023/11/29 00:00:00+00      1530     1536
# 18   -8.479620e+06  5.322322e+06  2023/07/25 00:00:00+00      1959     2030
# 22   -8.477073e+06  5.318898e+06  2023/06/10 00:00:00+00      2100     2300
# ...            ...           ...                     ...       ...      ...
# 6507 -8.476631e+06  5.321087e+06  2023/10/03 00:00:00+00      1513     1513
# 6508 -8.477529e+06  5.321606e+06  2023/10/28 00:00:00+00      1130     1135
# 6528 -8.478278e+06  5.323327e+06  2023/09/02 00:00:00+00      1205     1206
# 6535 -8.477704e+06  5.320980e+06  2023/08/25 00:00:00+00      1335     1335
# 6581 -8.474752e+06  5.319894e+06  2023/09/04 00:00:00+00      0630      946
#
# ...

# %%
allCrimeData = pd.concat([Crime2023Part1, Crime2023Part2, Crime2024Part1, Crime2024Part2], ignore_index=True)
allCrimeData.drop(columns=[ 'QualityOfLife', 'ObjectId', 'Arrest', 'LarcenyCode' ], inplace=True)

# %%
allCrimeData
# Out:
#                  X             Y                 DATEEND TIMESTART  TIMEEND  \
# 0    -8.479620e+06  5.322322e+06  2023/08/24 00:00:00+00      1341     1341
# 1    -8.479620e+06  5.322322e+06  2023/08/24 00:00:00+00      1730     1730
# 2    -8.479620e+06  5.322322e+06  2023/11/29 00:00:00+00      1530     1536
# 3    -8.477065e+06  5.319665e+06  2023/03/26 00:00:00+00      0525      530
# 4    -8.479620e+06  5.322322e+06  2023/07/25 00:00:00+00      1959     2030
# ...            ...           ...                     ...       ...      ...
# 8341 -8.476023e+06  5.321743e+06  2024/01/13 05:00:00+00         1       15
# 8342 -8.476075e+06  5.318279e+06  2024/01/13 05:00:00+00       313      313
# 8343 -8.476856e+06  5.316991e+06  2024/01/12 05:00:00+00      2318     2318
# 8344 -8.476908e+06  5.321811e+06  2024/01/13 05:00:00+00       136      136
# 8345 -8.477362e+06  5.321635e+06  2024/01/13 05:00:00+00       854      854
#
# ...

# %%
allCrimeData.isna().sum()
# Out:
# X               0
# Y               0
# DATEEND         0
# TIMESTART       0
# TIMEEND         0
# ADDRESS         0
# CODE_DEFINED    0
# LAT             0
# LONG            0
# dtype: int64

# %%
unique_values = allCrimeData['CODE_DEFINED'].unique()
print(unique_values)
# Out:
# ['LARCENY' 'MV THEFT' 'BURGLARY' 'ROBBERY' 'OFFN AGAINST FAMILY'
#  'DISORDERLY CONDUCT' 'SIMPLE ASSAULT' 'ALL OTHER OFFENSES'
#  'CRIMINAL MISCHIEF' 'DRIVING UNDER INFLUENCE'
#  'POSSESSION/USE DANGEROUS WEAPONS' 'FRAUD' 'POSSESSION/USE DRUG'
#  'KIDNAPPING' 'LOITERING' 'FORGERY/COUNTERFEIT' 'STOLEN PROPERTY'
#  'UNAUTHORIZED USE MV' 'COERCION' 'EXTORTION'
#  'PROSTITUTION PATRON/PROMOTING' 'SALE/MANUFACTURE CONTROLLED SUBSTANCE'
#  'POSSESSION/MARIJUANA' 'LIQUOR LAW VIOLATIONS']

# %%
crimeWeights = {
    "LARCENY": 2,
    "MV THEFT": 2,
    "BURGLARY": 10,
    "ROBBERY": 10,
    "OFFN AGAINST FAMILY": 5,
    "DISORDERLY CONDUCT": 2,
    "SIMPLE ASSAULT": 5,
    "ALL OTHER OFFENSES": 2,
    "CRIMINAL MISCHIEF": 5,
    "DRIVING UNDER INFLUENCE": 10,
    "POSSESSION/USE DANGEROUS WEAPONS": 10,
    "FRAUD": 10,
    "POSSESSION/USE DRUG": 10,
    "KIDNAPPING": 50,
    "LOITERING": 5,
    "FORGERY/COUNTERFEIT": 10,
    "STOLEN PROPERTY": 20,
    "UNAUTHORIZED USE MV": 10,
    "COERCION": 10,
    "EXTORTION": 20,
    "PROSTITUTION PATRON/PROMOTING": 25,
    "SALE/MANUFACTURE CONTROLLED SUBSTANCE": 15,
    "POSSESSION/MARIJUANA": 15,
    "LIQUOR LAW VIOLATIONS": 20
}

# Group the data by address and calculate the sum of crime weights
address_crime_weights = allCrimeData.groupby('ADDRESS')['CODE_DEFINED'].apply(lambda x: x.map(crimeWeights).sum())

# Assign the crime weights to the addresses
allCrimeData['CRIME_WEIGHT'] = allCrimeData['ADDRESS'].map(address_crime_weights)

allCrimeData

allCrimeData.to_csv('allCrimeData.csv', index=False)

# %%
import folium
from IPython.display import IFrame
from folium.plugins import HeatMap

# Create a map object
m = folium.Map(location=['43.067961', '-76.173723'], zoom_start=12)

smallCrimes = allCrimeData[allCrimeData['CRIME_WEIGHT'] < 100]
mediumCrimes = allCrimeData[(allCrimeData['CRIME_WEIGHT'] >= 100) & (allCrimeData['CRIME_WEIGHT'] < 500)]
largeCrimes = allCrimeData[allCrimeData['CRIME_WEIGHT'] >= 500]

# Create heatmap layers
heatmap_layer = HeatMap(data=smallCrimes[['LAT', 'LONG']], radius=10, color='green')
heatmap_layer2 = HeatMap(data=mediumCrimes[['LAT', 'LONG']], radius=10, color='orange')
heatmap_layer3 = HeatMap(data=largeCrimes[['LAT', 'LONG']], radius=10, color='red')

# Add the heatmap layers to the map
heatmap_layer.add_to(m)
heatmap_layer2.add_to(m)
heatmap_layer3.add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
smallCrimes = allCrimeData[allCrimeData['CRIME_WEIGHT'] < 20]
mediumCrimes = allCrimeData[(allCrimeData['CRIME_WEIGHT'] >= 20) & (allCrimeData['CRIME_WEIGHT'] < 500)]
largeCrimes = allCrimeData[allCrimeData['CRIME_WEIGHT'] >= 500]

smallCrimes
mediumCrimes
largeCrimes
# Out:
#                  X             Y                 DATEEND TIMESTART  TIMEEND  \
# 0    -8.479620e+06  5.322322e+06  2023/08/24 00:00:00+00      1341     1341
# 1    -8.479620e+06  5.322322e+06  2023/08/24 00:00:00+00      1730     1730
# 2    -8.479620e+06  5.322322e+06  2023/11/29 00:00:00+00      1530     1536
# 4    -8.479620e+06  5.322322e+06  2023/07/25 00:00:00+00      1959     2030
# 6    -8.479620e+06  5.322322e+06  2023/08/17 00:00:00+00      0003        3
# ...            ...           ...                     ...       ...      ...
# 8195 -8.479620e+06  5.322322e+06  2024/02/22 05:00:00+00      1405     1405
# 8258 -8.479620e+06  5.322322e+06  2024/02/09 05:00:00+00       747      747
# 8289 -8.479620e+06  5.322322e+06  2024/01/27 05:00:00+00      1359     1359
# 8308 -8.476707e+06  5.319201e+06  2024/01/12 05:00:00+00      1340     1340
# 8333 -8.479620e+06  5.322322e+06  2024/01/12 05:00:00+00      1900     2130
#
# ...

# %%
import requests
for index, row in largeCrimes.iterrows():
    coordinates = (row['LAT'], row['LONG'])
    print("Current coordinates: ", coordinates)

    # Define the API endpoint
    url = "https://roads.googleapis.com/v1/nearestRoads"

    # Define the API parameters
    params = {
        "points": f"{coordinates[0]},{coordinates[1]}",
        "key": "AIzaSyAAFSFl1024iEV_upockgRh5GZ7Svpi_Bk"
    }

    # Send the request to the API
    response = requests.get(url, params=params)

    # Update the values in the row
    largeCrimes.at[index, 'LAT'] = response.json()['snappedPoints'][0]['location']['latitude']
    largeCrimes.at[index, 'LONG'] = response.json()['snappedPoints'][0]['location']['longitude']
    print(response.json()['snappedPoints'][0]['location']['latitude'], response.json()['snappedPoints'][0]['location']['longitude'])
# Out:
# Current coordinates:  (43.067961, -76.1737229999999)
# 43.06779339999999 -76.1738371
# Current coordinates:  (43.067961, -76.1737229999999)
# 43.06779339999999 -76.1738371
# Current coordinates:  (43.067961, -76.1737229999999)
# 43.06779339999999 -76.1738371
# Current coordinates:  (43.067961, -76.1737229999999)
# 43.06779339999999 -76.1738371
# Current coordinates:  (43.067961, -76.1737229999999)
# 43.06779339999999 -76.1738371
# Current coordinates:  (43.067961, -76.1737229999999)
# 43.06779339999999 -76.1738371
# Current coordinates:  (43.067961, -76.1737229999999)
# 43.06779339999999 -76.1738371
# Current coordinates:  (43.067961, -76.1737229999999)
# 43.06779339999999 -76.1738371
# Current coordinates:  (43.067961, -76.1737229999999)
# 43.06779339999999 -76.1738371
# Current coordinates:  (43.067961, -76.1737229999999)
# 43.06779339999999 -76.1738371
# Current coordinates:  (43.067961, -76.1737229999999)
# 43.06779339999999 -76.1738371
# ...

# %%
import requests
for index, row in smallCrimes.iterrows():
    coordinates = (row['LAT'], row['LONG'])
    print("Current coordinates: ", coordinates)

    # Define the API endpoint
    url = "https://roads.googleapis.com/v1/nearestRoads"

    # Define the API parameters
    params = {
        "points": f"{coordinates[0]},{coordinates[1]}",
        "key": "AIzaSyAAFSFl1024iEV_upockgRh5GZ7Svpi_Bk"
    }

    # Send the request to the API
    response = requests.get(url, params=params)
    try:
        response.json()['snappedPoints'][0]['location']['latitude']
    except:
        continue
    # Update the values in the row
    smallCrimes.at[index, 'LAT'] = response.json()['snappedPoints'][0]['location']['latitude']
    smallCrimes.at[index, 'LONG'] = response.json()['snappedPoints'][0]['location']['longitude']
    print(response.json()['snappedPoints'][0]['location']['latitude'], response.json()['snappedPoints'][0]['location']['longitude'])
# Out:
# Current coordinates:  (43.050519095459464, -76.15077176555599)
# 43.050519095459464 -76.15077176555599
# Current coordinates:  (43.04548136240157, -76.15084528656415)
# 43.04548136240157 -76.15084528656415
# Current coordinates:  (43.04036361721359, -76.14234478112898)
# 43.0403636172136 -76.14234478112898
# Current coordinates:  (43.047056366040195, -76.15216252281)
# 43.047056366040195 -76.15216252281
# Current coordinates:  (43.02696807602141, -76.14595546622135)
# 43.02696807602141 -76.14595546622137
# Current coordinates:  (43.02063052679955, -76.14295877870468)
# 43.02063052679955 -76.14295877870468
# Current coordinates:  (43.02063052679955, -76.14295877870468)
# 43.02063052679955 -76.14295877870468
# Current coordinates:  (43.02063052679955, -76.14295877870468)
# 43.02063052679955 -76.14295877870468
# Current coordinates:  (43.047056366040195, -76.15216252281)
# 43.047056366040195 -76.15216252281
# Current coordinates:  (43.050537530898204, -76.15210718237017)
# ...

# %%
largeCrimes
# Out:
#                  X             Y                 DATEEND TIMESTART  TIMEEND  \
# 0    -8.479620e+06  5.322322e+06  2023/08/24 00:00:00+00      1341     1341
# 1    -8.479620e+06  5.322322e+06  2023/08/24 00:00:00+00      1730     1730
# 2    -8.479620e+06  5.322322e+06  2023/11/29 00:00:00+00      1530     1536
# 4    -8.479620e+06  5.322322e+06  2023/07/25 00:00:00+00      1959     2030
# 6    -8.479620e+06  5.322322e+06  2023/08/17 00:00:00+00      0003        3
# ...            ...           ...                     ...       ...      ...
# 8195 -8.479620e+06  5.322322e+06  2024/02/22 05:00:00+00      1405     1405
# 8258 -8.479620e+06  5.322322e+06  2024/02/09 05:00:00+00       747      747
# 8289 -8.479620e+06  5.322322e+06  2024/01/27 05:00:00+00      1359     1359
# 8308 -8.476707e+06  5.319201e+06  2024/01/12 05:00:00+00      1340     1340
# 8333 -8.479620e+06  5.322322e+06  2024/01/12 05:00:00+00      1900     2130
#
# ...

# %%
mediumCrimes
# Out:
#                  X             Y                 DATEEND TIMESTART  TIMEEND  \
# 46   -8.477382e+06  5.318739e+06  2023/05/19 00:00:00+00      2323     2323
# 47   -8.477382e+06  5.318739e+06  2023/05/24 00:00:00+00      1505     1505
# 48   -8.477382e+06  5.318739e+06  2023/07/17 00:00:00+00      1932     1932
# 50   -8.477382e+06  5.318739e+06  2023/12/25 00:00:00+00      2007     2007
# 70   -8.469838e+06  5.318558e+06  2023/10/20 00:00:00+00      1220     1220
# ...            ...           ...                     ...       ...      ...
# 8282 -8.476389e+06  5.321376e+06  2024/01/12 05:00:00+00      1157     1157
# 8304 -8.476202e+06  5.320346e+06  2024/01/12 05:00:00+00      1407     1407
# 8316 -8.476202e+06  5.320346e+06  2024/01/12 05:00:00+00      1601     1601
# 8330 -8.476634e+06  5.315497e+06  2024/01/12 05:00:00+00      2317     2317
# 8340 -8.476282e+06  5.320497e+06  2024/02/14 05:00:00+00       708      708
#
# ...

# %%
smallCrimes
# Out:
#                  X             Y                 DATEEND TIMESTART  TIMEEND  \
# 3    -8.477065e+06  5.319665e+06  2023/03/26 00:00:00+00      0525      530
# 5    -8.477073e+06  5.318898e+06  2023/06/10 00:00:00+00      2100     2300
# 52   -8.476124e+06  5.318118e+06  2023/09/06 00:00:00+00      1700     2308
# 53   -8.477220e+06  5.319129e+06  2023/06/20 00:00:00+00      1340     1410
# 54   -8.476522e+06  5.316080e+06  2023/03/14 00:00:00+00      1430     1757
# ...            ...           ...                     ...       ...      ...
# 8341 -8.476023e+06  5.321743e+06  2024/01/13 05:00:00+00         1       15
# 8342 -8.476075e+06  5.318279e+06  2024/01/13 05:00:00+00       313      313
# 8343 -8.476856e+06  5.316991e+06  2024/01/12 05:00:00+00      2318     2318
# 8344 -8.476908e+06  5.321811e+06  2024/01/13 05:00:00+00       136      136
# 8345 -8.477362e+06  5.321635e+06  2024/01/13 05:00:00+00       854      854
#
# ...

# %%
dataM = pd.read_csv('./mediumCrimes.csv')

# %%
dataM.shape
# Out:
# (1172, 10)

# %%
import folium
from IPython.display import IFrame
from folium.plugins import HeatMap

# Create a map object
m = folium.Map(location=['43.067961', '-76.173723'], zoom_start=12)

# Create heatmap layers
heatmap_layer = HeatMap(data=dataM[['latitude', 'longitude']], radius=10, color='blue')
heatmap_layer.add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
goodWaypoints =[(43.038497, -76.180731),(43.041114, -76.169333), (43.034190, -76.168420),(43.025417, -76.160784),(43.023092, -76.145535), (43.022107, -76.150100), (43.044238, -76.138307) ]
